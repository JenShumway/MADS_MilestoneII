# %%
import pandas as pd

# %%
# Load all

# OECD HCQI // Healthcare Quality Indicators
hcqi = pd.read_csv("../OECD/HEALTH_HCQI_22092023205825625.csv")

# OECD LVNG // Non-Medical Determinants of Health
lvng = pd.read_csv("../OECD/HEALTH_LVNG_25092023023230295.csv")

# OECD STAT // Health Statistics
stat = pd.read_csv("../OECD/HEALTH_STAT_25092023023520080.csv")

# OECD PROT // Social Protection
prot = pd.read_csv("../OECD/HEALTH_PROT_22092023205920251.csv")

# OECD DEMR // Demographics
demr = pd.read_csv("../OECD/HEALTH_DEMR_25092023023656863.csv")

# OECD ECOR // Economic References
ecor = pd.read_csv("../OECD/HEALTH_ECOR_28092023052908229.csv")

oecd_datasets = [hcqi, lvng, stat, prot, demr, ecor]

# %%
# Preliminary Cleaning

def clean_oecd_df(df):
    """Removes redundant or unneeded columns from OECD datasets"""

    df.drop(['Flag Codes', 'Flags'], axis=1, inplace=True)
    if 'YEA' in df.columns:
        df.drop(['YEA'], axis=1, inplace=True)
    else:
        df.drop(['PER'], axis=1, inplace=True)

    return df

oecd_datasets = [clean_oecd_df(x) for x in oecd_datasets]

# Renaming columns in HCQI to match other datasets
hcqi.rename(columns={'Indicator': 'Variable', 'IND': 'VAR', 'Periods': 'Year', 'Value': 'Measure'}, inplace=True)

hcqi.head()
# Out:
#    COU    Country  Year       VAR                   Variable GEN Gender  \
# 0  AUS  Australia  2011  ADMRASTH  Asthma hospital admission   M   Male
# 1  AUS  Australia  2011  ADMRASTH  Asthma hospital admission   M   Male
# 2  AUS  Australia  2011  ADMRASTH  Asthma hospital admission   M   Male
# 3  AUS  Australia  2012  ADMRASTH  Asthma hospital admission   M   Male
# 4  AUS  Australia  2012  ADMRASTH  Asthma hospital admission   M   Male
#
#         AGE              Age Group               VAL  \
# 0  TOTAL_15  15 years old and over  AS_STD_RATE_MPOP
# 1  TOTAL_15  15 years old and over            LOW_CI
# 2  TOTAL_15  15 years old and over             UP_CI
# 3  TOTAL_15  15 years old and over  AS_STD_RATE_MPOP
# 4  TOTAL_15  15 years old and over            LOW_CI
#
#                                             Measure  Value.1
# 0  Age-sex standardised rate per 100 000 population     40.4
# 1                         Lower confidence interval     39.1
# 2                         Upper confidence interval     41.8
# 3  Age-sex standardised rate per 100 000 population     36.8
# 4                         Lower confidence interval     35.5

# %%
# Reformatting HCQI data for merging

# Rename rows with more info
hcqi['Measure'] = hcqi['Gender'] + ', ' + hcqi['Age Group'] + ', ' + hcqi['Measure']
hcqi['VAR'] = hcqi['VAR'] + '_' + hcqi['GEN'] + '_' + hcqi['AGE'] + '_' + hcqi['VAL']
hcqi = hcqi[['VAR', 'Variable', 'Measure']]

oecd_datasets[0] = hcqi

hcqi.head()
# Out:
#                                     VAR                   Variable  \
# 0  ADMRASTH_M_TOTAL_15_AS_STD_RATE_MPOP  Asthma hospital admission
# 1            ADMRASTH_M_TOTAL_15_LOW_CI  Asthma hospital admission
# 2             ADMRASTH_M_TOTAL_15_UP_CI  Asthma hospital admission
# 3  ADMRASTH_M_TOTAL_15_AS_STD_RATE_MPOP  Asthma hospital admission
# 4            ADMRASTH_M_TOTAL_15_LOW_CI  Asthma hospital admission
#
#                                              Measure
# 0  Male, 15 years old and over, Age-sex standardi...
# 1  Male, 15 years old and over, Lower confidence ...
# 2  Male, 15 years old and over, Upper confidence ...
# 3  Male, 15 years old and over, Age-sex standardi...
# 4  Male, 15 years old and over, Lower confidence ...

# %%
df = pd.concat(oecd_datasets[:])[['VAR', 'Variable', 'Measure']].drop_duplicates() # Merge and remove duplicate rows
# match it to look like World Bank one and so the same functions can work for the World Bank or OECD
df.columns = ['indicator_code', 'indicator_name', 'definition_or_additional_info'] # Rename to match format

df.head()
# Out:
#                          indicator_code  \
# 0  ADMRASTH_M_TOTAL_15_AS_STD_RATE_MPOP
# 1            ADMRASTH_M_TOTAL_15_LOW_CI
# 2             ADMRASTH_M_TOTAL_15_UP_CI
# 6  ADMRCOPD_M_TOTAL_15_AS_STD_RATE_MPOP
# 7            ADMRCOPD_M_TOTAL_15_LOW_CI
#
#                                       indicator_name  \
# 0                          Asthma hospital admission
# 1                          Asthma hospital admission
# 2                          Asthma hospital admission
# 6  Chronic obstructive pulmonary disease hospital...
# 7  Chronic obstructive pulmonary disease hospital...
#
#                                      long_definition
# 0  Male, 15 years old and over, Age-sex standardi...
# 1  Male, 15 years old and over, Lower confidence ...
# 2  Male, 15 years old and over, Upper confidence ...
# 6  Male, 15 years old and over, Age-sex standardi...
# 7  Male, 15 years old and over, Lower confidence ...

# %%
df.to_csv('../OECD/Cleaned/OECD_Indicator_Definition_Info.csv', index=False)
